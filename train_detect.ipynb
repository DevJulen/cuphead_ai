# %% [markdown]
# # Import dependencies

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# %cd ..

import torch
from matplotlib import pyplot as plt
import numpy as np
# Out:
# c:\Users\julen\Documents\TFG\project\prueba\yolov5
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\julen\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\julen\appdata\local\programs\python\python39\lib\site-packages)
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\julen\Documents\TFG\project\prueba

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='r', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\julen/.cache\torch\hub\master.zip
# YOLOv5  2023-5-25 Python-3.9.13 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
# !python detect.py --weights colab2.pt --source area_down.jpg
# Out:
# python: can't open file 'c:\Users\julen\Documents\TFG\project\prueba\detect.py': [Errno 2] No such file or directory

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 8 --epochs 60 --data custom.yaml --weights yolov5s.pt --cache
# Out:
# ^C

# %%
img = 'experiments/images/80109601633735152519360557447973932263.jpg'
results = model(img)
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()
